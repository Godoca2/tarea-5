# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Dataset Iris
df_iris = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/iris-data.csv')
print(df.shape) # Mostrar las dimensiones
# 2. Mostrar las primeras (5) filas
df_iris.head()
# Out:
# (150, 5)
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df_iris.info() # Mostrar información del dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Verificar la existencia de valores nulos en df_iris
df_iris_null = df_iris.isnull().any().any()
print(f"¿Existen valores nulos en df_iris? {df_iris_null}")
# Out:
# ¿Existen valores nulos en df_iris? False

# %%
df_iris.describe() # Mostrar estadísticas del dataset
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df_iris.rename(columns={'class': 'Species'}, inplace=True)

# %% [markdown]
# El gráfico anterior muestra la relación entre la longitud y la anchura de los sépalos. Ahora comprobaremos la relación entre la longitud y la anchura de los pétalos.

# %%
plt.style.use('ggplot')

fig = df_iris[df_iris.Species=='Iris-setosa'].plot(kind='scatter',x='sepal length',y='sepal width',color='orange', label='Iris-setosa')
df_iris[df_iris.Species=='Iris-versicolor'].plot(kind='scatter',x='sepal length',y='sepal width',color='blue', label='Iris-versicolor',ax=fig)
df_iris[df_iris.Species=='Iris-virginica'].plot(kind='scatter',x='sepal length',y='sepal width',color='green', label='Iris-virginica', ax=fig)
fig.set_xlabel("sepal length")
fig.set_ylabel("sepal width")
fig.set_title("sepal length VS width")
plt.grid(True)
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
fig = df_iris[df_iris.Species=='Iris-setosa'].plot.scatter(x='petal length',y='petal width',color='orange', label='Iris-setosa')
df_iris[df_iris.Species=='Iris-versicolor'].plot.scatter(x='petal length',y='petal width',color='blue', label='Iris-versicolor',ax=fig)
df_iris[df_iris.Species=='Iris-virginica'].plot.scatter(x='petal length',y='petal width',color='green', label='Iris-virginica', ax=fig)
fig.set_xlabel("petal length")
fig.set_ylabel("petal width")
fig.set_title(" petal length VS width")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %% [markdown]
# Como podemos ver, las características de los pétalos ofrecen una mejor división de grupos en comparación con las características de los sépalos. Esto indica que los pétalos pueden ayudar a realizar predicciones mejores y más precisas que los sépalos. Lo comprobaremos más adelante.
#
# Veamos ahora cómo se distribuyen la longitud y la anchura.

# %%
plt.style.use('ggplot')
df_iris.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='petal length',data=df_iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='petal width',data=df_iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='sepal length',data=df_iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='sepal width',data=df_iris)
# Out:
# <Axes: xlabel='Species', ylabel='sepal width'>
